# %% [markdown]
# <a href="https://colab.research.google.com/github/ertgrulyksk/TED-Talk-analyzes/blob/main/TED_Talk_analyzes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
df=pd.read_csv("data (2).csv")

# %%
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2  https://ted.com/talks/martin_reeves_how_play_c...
# 3  https://ted.com/talks/james_k_thornton_why_is_...
# ...

# %%
df.shape
# Out:
# (5440, 6)

# %%
df.tail()
# Out:
#                                 title            author           date  \
# 5435  The best stats you've ever seen      Hans Rosling  February 2006
# 5436      Do schools kill creativity?  Sir Ken Robinson  February 2006
# 5437              Greening the ghetto     Majora Carter  February 2006
# 5438                 Simplicity sells       David Pogue  February 2006
# 5439      Averting the climate crisis           Al Gore  February 2006
#
#          views    likes                                               link
# 5435  15000000   458000  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  72000000  2100000  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437   2900000    88000  https://ted.com/talks/majora_carter_greening_t...
# 5438   2000000    60000  https://ted.com/talks/david_pogue_simplicity_s...
# 5439   3600000   109000  https://ted.com/talks/al_gore_averting_the_cli...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5440 non-null   object
#  1   author  5439 non-null   object
#  2   date    5440 non-null   object
#  3   views   5440 non-null   int64
#  4   likes   5440 non-null   int64
#  5   link    5440 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 255.1+ KB

# %%
df[df.isna().any(axis=1)]
# Out:
#                    title author           date  views  likes  \
# 3039  Year In Ideas 2015    NaN  December 2015    532     15
#
#                                           link
# 3039  https://ted.com/talks/year_in_ideas_2015

# %%
df_new=df.fillna("People et al.")

# %%
df_new[df_new.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [title, author, date, views, likes, link]
# Index: []

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5440 non-null   object
#  1   author  5440 non-null   object
#  2   date    5440 non-null   object
#  3   views   5440 non-null   int64
#  4   likes   5440 non-null   int64
#  5   link    5440 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 255.1+ KB

# %%
duplicateRowsDF = df_new[df_new.duplicated()] #find all duplicated rows

# %%
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [title, author, date, views, likes, link]
# Index: []

# %%
df_new.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2  https://ted.com/talks/martin_reeves_how_play_c...
# 3  https://ted.com/talks/james_k_thornton_why_is_...
# ...

# %%
df_new.tail()
# Out:
#                                 title            author           date  \
# 5435  The best stats you've ever seen      Hans Rosling  February 2006
# 5436      Do schools kill creativity?  Sir Ken Robinson  February 2006
# 5437              Greening the ghetto     Majora Carter  February 2006
# 5438                 Simplicity sells       David Pogue  February 2006
# 5439      Averting the climate crisis           Al Gore  February 2006
#
#          views    likes                                               link
# 5435  15000000   458000  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  72000000  2100000  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437   2900000    88000  https://ted.com/talks/majora_carter_greening_t...
# 5438   2000000    60000  https://ted.com/talks/david_pogue_simplicity_s...
# 5439   3600000   109000  https://ted.com/talks/al_gore_averting_the_cli...

# %%
import seaborn as sns
# %matplotlib inline

# %%
df_new.max(numeric_only=True)
# Out:
# views    72000000
# likes     2100000
# dtype: int64

# %%
df_new[df_new.likes == df_new.likes.max()]
# Out:
#                             title            author           date     views  \
# 5436  Do schools kill creativity?  Sir Ken Robinson  February 2006  72000000
#
#         likes                                               link
# 5436  2100000  https://ted.com/talks/sir_ken_robinson_do_scho...

# %%
df_new[df_new.views == df_new.views.max()]
# Out:
#                             title            author           date     views  \
# 5436  Do schools kill creativity?  Sir Ken Robinson  February 2006  72000000
#
#         likes                                               link
# 5436  2100000  https://ted.com/talks/sir_ken_robinson_do_scho...

# %%
df_new[df_new.views == df_new.views.min()]
# Out:
#                    title         author           date  views  likes  \
# 3039  Year In Ideas 2015  People et al.  December 2015    532     15
#
#                                           link
# 3039  https://ted.com/talks/year_in_ideas_2015

# %%
df_new[df_new.likes == df_new.likes.min()]
# Out:
#                    title         author           date  views  likes  \
# 3039  Year In Ideas 2015  People et al.  December 2015    532     15
#
#                                           link
# 3039  https://ted.com/talks/year_in_ideas_2015

# %%
df_likes=df_new.sort_values('likes',ascending = False).groupby('title')

# %%
df_likes.head(5)
# Out:
#                                                   title  \
# 5436                        Do schools kill creativity?
# 4084           Your body language may shape who you are
# 2958         Inside the mind of a master procrastinator
# 4605                         The power of vulnerability
# 4765                   How great leaders inspire action
# ...                                                 ...
# 1692  "Part II. The Journey Through Time" / "Ruslan ...
# 1064  "Jamie Raeburn" / "Baloo Baleerie" / "Twa recr...
# 552                                      Virtual Worlds
# 613                  Post-Pandemic Paradise in Rapa Nui
# 3039                                 Year In Ideas 2015
#
#                                 author            date     views    likes  \
# 5436                  Sir Ken Robinson   February 2006  72000000  2100000
# 4084                         Amy Cuddy       June 2012  64000000  1900000
# ...

# %%
df_new.nlargest(n=5, columns=['likes'])
# Out:
#                                            title            author  \
# 5436                 Do schools kill creativity?  Sir Ken Robinson
# 4084    Your body language may shape who you are         Amy Cuddy
# 2958  Inside the mind of a master procrastinator         Tim Urban
# 4605                  The power of vulnerability       Brené Brown
# 4765            How great leaders inspire action       Simon Sinek
#
#                 date     views    likes  \
# 5436   February 2006  72000000  2100000
# 4084       June 2012  64000000  1900000
# 2958   February 2016  60000000  1800000
# 4605       June 2010  56000000  1700000
# 4765  September 2009  57000000  1700000
#
#                                                    link
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 4084  https://ted.com/talks/amy_cuddy_your_body_lang...
# 2958  https://ted.com/talks/tim_urban_inside_the_min...
# 4605  https://ted.com/talks/brene_brown_the_power_of...
# ...

# %%
df_new.nlargest(n=5, columns=['views'])
# Out:
#                                            title            author  \
# 5436                 Do schools kill creativity?  Sir Ken Robinson
# 4084    Your body language may shape who you are         Amy Cuddy
# 2958  Inside the mind of a master procrastinator         Tim Urban
# 4765            How great leaders inspire action       Simon Sinek
# 4605                  The power of vulnerability       Brené Brown
#
#                 date     views    likes  \
# 5436   February 2006  72000000  2100000
# 4084       June 2012  64000000  1900000
# 2958   February 2016  60000000  1800000
# 4765  September 2009  57000000  1700000
# 4605       June 2010  56000000  1700000
#
#                                                    link
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 4084  https://ted.com/talks/amy_cuddy_your_body_lang...
# 2958  https://ted.com/talks/tim_urban_inside_the_min...
# 4765  https://ted.com/talks/simon_sinek_how_great_le...
# ...

# %%
ten_most_viewed_talks = df_new.sort_values("views").tail(10)

# %%
ten_most_viewed_talks[['author','views']].head(10)
# Out:
#                 author     views
# 3994   Cameron Russell  38000000
# 3017  Robert Waldinger  41000000
# 2168         Sam Berns  43000000
# 3251        Bill Gates  43000000
# 3504   Julian Treasure  49000000
# 4605       Brené Brown  56000000
# 4765       Simon Sinek  57000000
# 2958         Tim Urban  60000000
# 4084         Amy Cuddy  64000000
# 5436  Sir Ken Robinson  72000000

# %%
df_new['author'].value_counts().head()
# Out:
# Alex Gendler        45
# Iseult Gillespie    33
# Matt Walker         18
# Alex Rosenthal      15
# Elizabeth Cox       13
# Name: author, dtype: int64

# %%
import seaborn as sns
sns.countplot(y="author", data=df_new, palette="coolwarm",
              order=df_new.author.value_counts().iloc[:11].index)

# %%
df_new["date"]=pd.to_datetime(df_new["date"])

# %%
df_new.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#         date   views  likes                                               link
# 0 2021-12-01  404000  12000  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1 2022-02-01  214000   6400  https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2 2021-09-01  412000  12000  https://ted.com/talks/martin_reeves_how_play_c...
# 3 2021-10-01  427000  12000  https://ted.com/talks/james_k_thornton_why_is_...
# 4 2021-10-01    2400     72  https://ted.com/talks/mahendra_singhi_cement_s...

# %%
df_new['year']= df_new['date'].dt.year
df_new['month']= df_new['date'].dt.month
df_new['day']= df_new['date'].dt.day

# %%
df_new.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#         date   views  likes  \
# 0 2021-12-01  404000  12000
# 1 2022-02-01  214000   6400
# 2 2021-09-01  412000  12000
# 3 2021-10-01  427000  12000
# 4 2021-10-01    2400     72
#
#                                                 link  year  month  day
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...  2021     12    1
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...  2022      2    1
# 2  https://ted.com/talks/martin_reeves_how_play_c...  2021      9    1
# ...

# %%
del df_new["link"]

# %%
df_new.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#         date   views  likes  year  month  day
# 0 2021-12-01  404000  12000  2021     12    1
# 1 2022-02-01  214000   6400  2022      2    1
# 2 2021-09-01  412000  12000  2021      9    1
# 3 2021-10-01  427000  12000  2021     10    1
# 4 2021-10-01    2400     72  2021     10    1

# %%
nach_month=df_new.groupby("month").count()

# %%
nach_month
# Out:
#        title  author  date  views  likes  year  day
# month
# 1        147     147   147    147    147   147  147
# 2        725     725   725    725    725   725  725
# 3        580     580   580    580    580   580  580
# 4        576     576   576    576    576   576  576
# 5        322     322   322    322    322   322  322
# 6        493     493   493    493    493   493  493
# 7        446     446   446    446    446   446  446
# 8        200     200   200    200    200   200  200
# 9        349     349   349    349    349   349  349
# 10       585     585   585    585    585   585  585
# 11       682     682   682    682    682   682  682
# 12       335     335   335    335    335   335  335

# %%
df_month=df_new['month'].value_counts()

# %%
df_month
# Out:
# 2     725
# 11    682
# 10    585
# 3     580
# 4     576
# 6     493
# 7     446
# 9     349
# 12    335
# 5     322
# 8     200
# 1     147
# Name: month, dtype: int64

# %%
ax=sns.lineplot(data=nach_month, x="month", y="title")
ax.set_xlim(1,12)
ax.set_xticks(range(1,13))
ax.set( ylabel = "count")
ax.set_title(' TED talk frequency per month(2006-2021)')
# Out:
# Text(0.5, 1.0, ' TED talk frequency per month(2006-2021)')

# %%
nach_likes=df_new.groupby(["likes","month"]).sum().reset_index()

# %%
nach_likes
# Out:
#         likes  month     views  year  day
# 0          15     12       532  2015    1
# 1          37     10      1200  2020    1
# 2          39     11      1300  2020    1
# 3          40      7      1300  2019    1
# 4          40     11      1300  2018    1
# ...       ...    ...       ...   ...  ...
# 2231  1700000      6  56000000  2010    1
# 2232  1700000      9  57000000  2009    1
# 2233  1800000      2  60000000  2016    1
# 2234  1900000      6  64000000  2012    1
# 2235  2100000      2  72000000  2006    1
#
# [2236 rows x 5 columns]

# %%
nach_like_month= nach_likes.groupby(["month"]).sum().reset_index()

# %%
del nach_like_month["year"]

# %%
del nach_like_month["day"]

# %%
nach_like_month
# Out:
#     month     likes       views
# 0       1   7393042   302850399
# 1       2  35318356  1984575996
# 2       3  24887527  1375276896
# 3       4  20188030  1214604196
# 4       5  12113449   658259600
# 5       6  21727174  1164034699
# 6       7  14803756   864732799
# 7       8   4781049   295820997
# 8       9  10891272   606392100
# 9      10  16724140   965331498
# 10     11  19454294  1180802199
# 11     12  11858112   602291832

# %%
sns.barplot(y="likes", x="month", data=nach_like_month)

# %%
sns.barplot(y="views", x="month", data=nach_like_month)

# %%
sns.scatterplot(data=nach_like_month,x= "likes", y="views")

# %%
sns.scatterplot(data=nach_likes,x= "likes", y="views",hue="month")

# %%
nach_likes_new=df_new.groupby(["likes","year"]).count().reset_index()
#nach_like_year= nach_likes.groupby(["year"]).count().reset_index()
nach_likes_new
nach_like_year= nach_likes_new.groupby(["year"]).sum().reset_index()

# %%
nach_like_year
# Out:
#     year     likes  title  author  date  views  month  day
# 0   1970      7500      2       2     2      2      2    2
# 1   1972     41000      1       1     1      1      1    1
# 2   1983     20000      1       1     1      1      1    1
# 3   1984     33000      1       1     1      1      1    1
# 4   1990     21000      1       1     1      1      1    1
# 5   1991      9800      1       1     1      1      1    1
# 6   1994     20000      1       1     1      1      1    1
# 7   1998    212100      6       6     6      6      6    6
# 8   2001    300100      5       5     5      5      5    5
# 9   2002    880700     26      26    26     26     26   26
# 10  2003   1537400     34      34    34     34     34   34
# 11  2004   3422400     33      33    33     33     33   33
# 12  2005   4419000     65      65    65     65     65   65
# 13  2006   5177400     49      49    49     49     49   49
# 14  2007   4002100    113     113   113    113    113  113
# ...

# %%
import matplotlib.pyplot as plt
sns.barplot(y="likes", x="year", data=nach_like_year)
plt.tight_layout()

# %%
sns.lineplot(data=nach_like_year, x="year", y="likes")

# %%
df_new.sort_values('views')
# Out:
#                                                   title  \
# 3039                                 Year In Ideas 2015
# 613                  Post-Pandemic Paradise in Rapa Nui
# 552                                      Virtual Worlds
# 1064  "Jamie Raeburn" / "Baloo Baleerie" / "Twa recr...
# 1692  "Part II. The Journey Through Time" / "Ruslan ...
# ...                                                 ...
# 4605                         The power of vulnerability
# 4765                   How great leaders inspire action
# 2958         Inside the mind of a master procrastinator
# 4084           Your body language may shape who you are
# 5436                        Do schools kill creativity?
#
#                                 author       date     views    likes  year  \
# 3039                     People et al. 2015-12-01       532       15  2015
# 613                          Far Flung 2020-10-01      1200       37  2020
# ...

# %%
df_new["like_view_ratio"]=df_new["likes"] / df_new["views"]

# %%
ratio=df_new.sort_values('like_view_ratio').tail(5)

# %%
sns.barplot(x="like_view_ratio", y="title", data=ratio)

# %%
ratio_low=df_new.sort_values('like_view_ratio').head()

# %%
ratio_low
# Out:
#                                                   title            author  \
# 837   How to see more and care less: The art of Geor...  Iseult Gillespie
# 905                      What's the point(e) of ballet?         Ming Luke
# 955                A camera that can see around corners     David Lindell
# 1016             The function and fashion of eyeglasses    Debbie Millman
# 26    Can you outsmart the fallacy that divided a na...     Elizabeth Cox
#
#            date   views  likes  year  month  day  like_view_ratio
# 837  2020-06-01  364000  10000  2020      6    1         0.027473
# 905  2020-04-01  364000  10000  2020      4    1         0.027473
# 955  2019-11-01  364000  10000  2019     11    1         0.027473
# 1016 2020-01-01  363000  10000  2020      1    1         0.027548
# 26   2022-02-01  363000  10000  2022      2    1         0.027548

# %%
sns.barplot(x="like_view_ratio", y="title", data=ratio_low)

# %%
df_new.loc[df_new['title'].str.contains("climate", case=False)]
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 17              The ocean's ingenious climate solutions           Susan Ruffo
# 18    How we're reducing the climate impact of elect...              Tim Dunn
# 34    How to boost nature-based solutions to climate...         Zac Goldsmith
# ...                                                 ...                   ...
# 4892              The science behind a climate headline           Rachel Pike
# 5226                 New thinking on the climate crisis               Al Gore
# 5280  A critical look at geoengineering against clim...           David Keith
# 5389       Global priorities bigger than climate change         Bjorn Lomborg
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df_new.loc[df_new['title'].str.contains("Tesla", case=False)]
# Out:
#                                              title         author       date  \
# 3941  The mind behind Tesla, SpaceX, SolarCity ...      Elon Musk 2013-02-01
# 4170    The electric rise and fall of Nikola Tesla  Marco Tempest 2012-03-01
#
#         views   likes  year  month  day  like_view_ratio
# 3941  7800000  236000  2013      2    1         0.030256
# 4170  1800000   55000  2012      3    1         0.030556

# %%
df_new.loc[df_new['title'].str.contains("USA", case=False)]
# Out:
#                                                   title  \
# 1050  Usando la fotografía para celebrar los diferen...
# 1305  What happened when we paired up thousands of s...
# 1761  Cómo usar el arte de la fotografía para restau...
# 1870  What happened when we tested thousands of aban...
# 2110                   The truth about unwanted arousal
# 3215  Mansa Musa, one of the wealthiest people who e...
# 4087                                A thousand times no
#
#                       author       date    views   likes  year  month  day  \
# 1050           Angelica Dass 2013-09-01    60000    1800  2013      9    1
# 1305           Jochen Wegner 2019-07-01  1900000   58000  2019      7    1
# 1761  Alejandro Chaskielberg 2018-11-01    12000     389  2018     11    1
# 1870              Kym Worthy 2018-07-01  1700000   52000  2018      7    1
# 2110           Emily Nagoski 2018-04-01  2900000   88000  2018      4    1
# ...

# %%
popular_speaker=df_new.sort_values('views')[[ "author","views"]].tail(10)

# %%
sns.barplot(x="views", y="author", data=popular_speaker,palette="coolwarm")
